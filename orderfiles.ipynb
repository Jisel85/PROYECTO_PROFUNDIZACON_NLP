# %%
# %load_ext autoreload
# %autoreload 2
import os
from pathlib import Path
import pandas as pd
import sys
####
sys.path.append('/media/andres-campos/Archivos_Ubuntu/UCentral_Maestria/Students/Tesis/Director/PROYECTO_PROFUNDIZACON_NLP/src/')
from mi_test import Test
# Out:
# Conexión con scripts OK!

# %%
## Variables general
MAIN_PATH_FOLDER = Path(os.getcwd())
MAIN_PATH_FOLDER
# Out:
# PosixPath('/media/andres-campos/Archivos_Ubuntu/UCentral_Maestria/Students/Tesis/Director/PROYECTO_PROFUNDIZACON_NLP')

# %%
## Prueba pandas
df = pd.read_csv(MAIN_PATH_FOLDER / "data" / "Sentencias_Corte_1992-2022.csv")
df
# Out:
#       Sentencia                          Proceso Expediente Tipo
# 0      C-397-10         Convocatoria a Referendo             CRF  \
# 1      C-141-10         Convocatoria a Referendo             CRF
# 2      C-517-92  Demanda de inconstitucionalidad               D
# 3      C-279-96  Demanda de inconstitucionalidad               D
# 4      C-478-92  Demanda de inconstitucionalidad               D
# ...         ...                              ...             ...
# 16306  T-371-06                           Tutela               T
# 16307  T-570-06                           Tutela               T
# 16308  T-356-06                           Tutela               T
# 16309  T-511-06                           Tutela               T
# 16310  T-491-06                           Tutela               T
#
#        Expediente NÃºmero          Magistrado(a) ponente Sentencia Tipo
# 0                       2       Juan Carlos Henao PÃ©rez              C  \
# ...
